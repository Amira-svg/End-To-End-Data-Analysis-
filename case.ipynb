# %%
import pandas as pd
import numpy as np

df=pd.read_csv("D:/Clean data/final_project raw_case.csv")
df["Case_ID"] = pd.to_numeric(df["Case_ID"], errors="coerce")
case_mask = df["Patient_ID"] > 199999
df.loc[case_mask, "Patient_ID"] = np.random.randint(
    1, 200000, size=case_mask.sum()
)

df.to_csv("D:/بايثون/Case.csv", index=False)
