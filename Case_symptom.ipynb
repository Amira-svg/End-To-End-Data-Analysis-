# %%
import numpy as np
import pandas as pd
df=pd.read_csv("D:/Clean data/final_project raw_case_symptom.csv")
#pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
df["Case_ID"]=df["Case_ID"].astype(str)
df["Symptom_ID"]=df["Symptom_ID"].astype(str)
df["Symptom_Severity"]=df["Symptom_Severity"].astype(str)
df.to_csv("D:/بايثون/Case_symptom.csv", index=False)
